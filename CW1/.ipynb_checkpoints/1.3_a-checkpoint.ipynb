# %%
import scipy.io as sio
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import matplotlib.pyplot as plt
import timeit
import matplotlib as mpl

mpl.rcParams['figure.figsize'] = (10,15)
ds = sio.loadmat('face.mat')

# %%
X = ds['X']
l = ds['l'][0]
split = 0.8
W = 46
H = 56
IDs = 52
X = pd.DataFrame(X.transpose())
N = X.shape[0]*split
l = pd.DataFrame(l)

# %%
X_train, X_test, l_train, l_test = train_test_split(X, l, test_size=(1-split), stratify = l)
# X_bar = np.mean(X, axis=1)
X_train, X_test = X_train.values, X_test.values
l_train, l_test = l_train.values, np.transpose(l_test.values)
X_bar = np.transpose([np.mean(X_train, axis=0)])
X_bar = np.ndarray.flatten(X_bar)

# %%
train_subspaces = []
for i in range(IDs):
    images = []
    for j in range(int(N)):
        if l_train[j][0] == i+1:
            images.append(X_train[j])
    train_subspaces.append(images)

# %%
eigen_subspaces = []
elements = np.asarray(train_subspaces[0])
elements_mean = np.mean(elements, axis=0)
elements = np.subtract(elements,elements_mean)
S_W = np.matmul(elements.T,elements)
mean_diff = np.atleast_2d(elements_mean)-X_bar
S_B = np.matmul(mean_diff.T, mean_diff)
S = np.matmul(elements,np.transpose(elements))
w, v = np.linalg.eig(S)
U = preprocessing.normalize(np.matmul(np.transpose(elements),v), axis=0)
eigen_subspaces.append([U,elements_mean])
for i in range(1,IDs):
    elements = np.asarray(train_subspaces[i])
    elements_mean = np.mean(elements, axis=0)
    elements = np.subtract(elements,elements_mean)
    S_W += np.matmul(elements.T,elements)
    mean_diff = np.atleast_2d(elements_mean)-X_bar
    S_B += np.matmul(mean_diff.T, mean_diff)
    S = np.matmul(elements,np.transpose(elements))
    w, v = np.linalg.eig(S)
    U = preprocessing.normalize(np.matmul(np.transpose(elements),v), axis=0)
    eigen_subspaces.append([U,elements_mean])

# %%
print(np.linalg.matrix_rank(S_W))
print(np.linalg.matrix_rank(S_B))
print(N-52)
# Out:
# 364
# 51
# 364.0

# %%
S_WB = np.matmul(np.linalg.inv(S_W),S_B)
w_lda, v_lda = np.linalg.eig(S_WB)
plt.plot(w_lda[:50])
plt.ylabel('Eigenvalue')
plt.title('Eigenvalues for Low Dimensional PCA')
plt.show()

inds = w_lda.argsort()[::-1]
w_lda = w_lda[inds]
v_lda = v_lda[:,inds]
M_lda = 51
w_lda = w_lda[:M_lda]
v_lda = v_lda[:,:M_lda]


plt.plot(w_lda)
plt.ylabel('Eigenvalue')
plt.show()
# Out:
# c:\users\georg\appdata\local\programs\python\python35\lib\site-packages\numpy\core\numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
A = np.subtract(X_train,X_bar)
w_pca, v_pca = np.linalg.eig(np.matmul(A.T,A))
plt.plot(w_pca)
plt.ylabel('Eigenvalue')
plt.title('Eigenvalues for Low Dimensional PCA')
plt.show()
M_pca = int(N-M_lda)
w_pca = w_pca[:M_pca]
v_pca = v_pca[:,:M_pca]

plt.plot(np.abs(w_pca))
plt.ylabel('Eigenvalue')
plt.show()
# Out:
# c:\users\georg\appdata\local\programs\python\python35\lib\site-packages\numpy\core\numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
meh2 = np.dot(np.dot(v_pca.T,S_W),v_pca)
meh1 = np.dot(np.dot(v_pca.T,S_B),v_pca)
w_fld, v_fld = np.linalg.eig(np.linalg.inv(meh2).dot(meh1))
plt.plot(w_fld)
plt.ylabel('Eigenvalue')
plt.title('Eigenvalues for Low Dimensional PCA')
plt.show()
w_fld = w_fld[:M_lda]
v_fld = v_fld[:,:M_lda]

plt.plot(np.abs(w_fld))
plt.ylabel('Eigenvalue')
plt.show()
# Out:
# c:\users\georg\appdata\local\programs\python\python35\lib\site-packages\numpy\core\numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
# v_opt = np.zeros((2576,51))
# print(v_pca.shape)
# for i in range(2576):
#     for j in range(M_pca):
# #         print(i)
# #         print(j)
#         v_opt[i,j] = v_pca[i,j]*v_lda[i,j]
v_opt = np.dot(v_fld,v_lda)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-7caf24e8730c> in <module>()
#       6 # #         print(j)
#       7 #         v_opt[i,j] = v_pca[i,j]*v_lda[i,j]
# ----> 8 v_opt = np.dot(v_fld,v_lda)
#
# ValueError: shapes (365,51) and (2576,51) not aligned: 51 (dim 1) != 2576 (dim 0)

# %%
plt.figure(figsize=(15.0,9.0))
for i in range(1,9):
    eigen = np.transpose(v_opt)[i]
    eigenface = np.real(np.transpose(np.array_split(eigen/(np.max(eigen)), W)))
    ax = plt.subplot(2,4,i)
    ax.imshow(eigenface, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-e286b4885da8> in <module>()
#       4     eigenface = np.real(np.transpose(np.array_split(eigen/(np.max(eigen)), W)))
#       5     ax = plt.subplot(2,4,i)
# ----> 6     ax.imshow(eigenface, cmap='gray')
#
# c:\users\georg\appdata\local\programs\python\python35\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# c:\users\georg\appdata\local\programs\python\python35\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5470                               resample=resample, **kwargs)
#    5471
# -> 5472         im.set_data(X)
#    5473         im.set_alpha(alpha)
#    5474         if im.get_clip_path() is None:
#
# c:\users\georg\appdata\local\programs\python\python35\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     640         if (self._A.dtype != np.uint8 and
#     641                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 642             raise TypeError("Image data cannot be converted to float")
#     643
#     644         if not (self._A.ndim == 2
#
# TypeError: Image data cannot be converted to float

# %%
# correct = 0
# wrong = []
# right = []
# for j in range(len(l_test[0])):
#     error = []
#     for i in range(IDs):
#         test_img = X_test[j]-eigen_subspaces[i][1]
#         identity = np.matmul(test_img,eigen_subspaces[i][0])
#         recon = np.matmul(identity, np.transpose(eigen_subspaces[i][0]))+eigen_subspaces[i][1]
#         diff = X_test[j]-recon
#         error.append(np.matmul(diff,np.transpose(diff)))
#     guess = np.argmin(error)+1
#     if guess == l_test[0][j]:
#         correct += 1
#         right.append([[l_test[0][j], j], [guess]])
#     else:
#         wrong.append([[l_test[0][j], j], [guess]])
            
# print('Correct = '+str(round(100*correct/len(l_test[0]),2))+'%')

# %%
# plt.figure(figsize=(15.0,9.0))
# incorrect = wrong[0]
# guess = incorrect[1][0]-1
# train_img = np.asarray(train_subspaces[guess])[0]
# test_img = np.transpose(np.array_split(X_test[incorrect[0][1]], W))
# train_img = np.transpose(np.array_split(np.transpose(train_img), W))
# ax = plt.subplot(1, 2, 1)
# ax.imshow(test_img, cmap='gray')
# ax = plt.subplot(1, 2, 2)
# ax.imshow(train_img, cmap='gray')

# %%
# plt.figure(figsize=(15.0,9.0))
# correct = right[0]
# guess = correct[1][0]-1
# train_img = np.asarray(train_subspaces[guess])[0]
# test_img = np.transpose(np.array_split(X_test[correct[0][1]], W))
# train_img = np.transpose(np.array_split(np.transpose(train_img), W))
# ax = plt.subplot(1, 2, 1)
# ax.imshow(test_img, cmap='gray')
# ax = plt.subplot(1, 2, 2)
# ax.imshow(train_img, cmap='gray')
